# %%
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# notebook dir
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
print('notebook_dir', notebook_dir)

# config auto reload
# %load_ext autoreload
# %autoreload 2
# Out:
# notebook_dir /home/mingxuan/Repositories/scg_tsung/benchmarking_sim/quadrotor/plotting
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
controller = 'gpmpc_acados'
prior = 'results/200_200_noise'
controller = 'linear_mpc'
prior = 'resultsaggresive_noise'
controller = 'mpc_acados'
prior = 'results_noise/temp'
# controller = 'ilqr'
max_seed = 9
metric_name = 'metrics.txt'
s = 2 # times std
obs_dim = 6

# get the default color cycle
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

plot_color = {'ilqr': 'gray', 'gpmpc_acados': colors[0], 'mpc_acados':colors[-1], 'linear_mpc':colors[2]}

# %%
data_folder_dir = f'../{controller}/{prior}/'
# find the folder in the dir
seed_data_folder = os.listdir(os.path.join(notebook_dir, data_folder_dir))
print('seed_data_folder', seed_data_folder)
seed_data_folder = [f for f in seed_data_folder if os.path.isdir(os.path.join(data_folder_dir, f))]
seed_data_folder = sorted(seed_data_folder, key=lambda x: int(x.split('_')[1]))
# print('seed_data_folder', seed_data_folder)
print('max seed', max_seed)
# seed_data_folder = [seed_data_folder[i]+'/temp' for i in range(max_seed)]
# seed_data_folder = seed_data_folder[:9]
print('seed_data_folder', seed_data_folder)
seed_data_folder = [os.path.join(data_folder_dir, f) for f in seed_data_folder]
print('seed_data_folder', seed_data_folder)
# Out:
# seed_data_folder ['seed_9', 'seed_1', 'seed_6', 'seed_7', 'seed_4', 'seed_2', 'seed_8', 'seed_5', 'seed_3']
# max seed 9
# seed_data_folder ['seed_1', 'seed_2', 'seed_3', 'seed_4', 'seed_5', 'seed_6', 'seed_7', 'seed_8', 'seed_9']
# seed_data_folder ['../mpc_acados/results_noise/temp/seed_1', '../mpc_acados/results_noise/temp/seed_2', '../mpc_acados/results_noise/temp/seed_3', '../mpc_acados/results_noise/temp/seed_4', '../mpc_acados/results_noise/temp/seed_5', '../mpc_acados/results_noise/temp/seed_6', '../mpc_acados/results_noise/temp/seed_7', '../mpc_acados/results_noise/temp/seed_8', '../mpc_acados/results_noise/temp/seed_9']

# %%
results = {}

for seed in range(0, max_seed):
    results[repr(seed)] = {}
    rmse_list = []
    early_stop_list = []
    noise_factor_list = []
    traj_data_list = []
    traj_steps_list = []
    # fild runs
    load_seed_dir = seed_data_folder[seed]
    runs_data_folder = os.listdir(os.path.join(notebook_dir, load_seed_dir))
    runs_data_folder = [os.path.join(load_seed_dir, f) for f in runs_data_folder]
    # sort the runs
    runs_data_folder = sorted(runs_data_folder)
    print('runs_data_folder', runs_data_folder)
    for runs in runs_data_folder:
        # load the metric file in the folder
        metric_file = os.path.join(runs, metric_name)
        # print('metric_file', metric_file)
        data = pd.read_csv(metric_file, delimiter=':')
        # convert to numpy
        data = data.to_numpy()
        # print(data)
        # convert to dictionary
        data = {data[i][0]: data[i][1] for i in range(len(data))}

        noise_factor = eval(data['noise_factor'])
        rmse = eval(data['rmse'])
        early_stop = eval(data['early_stop'])
        rmse_list.append(rmse)
        early_stop_list.append(early_stop)
        noise_factor_list.append(noise_factor)

        # load the traj
        traj_file = os.path.join(runs, f'{controller}_data_quadrotor_traj_tracking.pkl')
        traj_data = pd.read_pickle(traj_file)
        traj_data = traj_data['trajs_data']['obs'][0]
        traj_steps = len(traj_data)
        traj_data_list.append(traj_data)
        traj_steps = len(traj_data)
        traj_steps_list.append(traj_steps)
    
    results[repr(seed)]['rmse'] = rmse_list
    results[repr(seed)]['early_stop'] = early_stop_list
    results[repr(seed)]['noise_factor'] = noise_factor_list
    # results[repr(seed)]['traj_data'] = traj_data_list
    results[repr(seed)]['traj_steps'] = traj_steps_list

max_noise_factor = max([max(results[repr(seed)]['noise_factor']) for seed in range(max_seed)])
# Out:
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-38-38_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-38-45_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-38-52_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-00_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-07_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-16_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-25_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-34_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-44_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-39-52_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-01_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-11_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-22_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-32_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-43_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-40-53_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-41-03_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-41-11_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-41-19_51e2c12', '../mpc_acados/results_noise/temp/seed_1/seed10_Oct-09-15-41-25_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-17-38_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-17-45_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-17-52_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-00_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-09_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-17_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-26_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-34_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-42_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-50_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-18-58_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-07_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-17_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-28_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-38_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-48_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-19-57_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-20-05_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-20-11_51e2c12', '../mpc_acados/results_noise/temp/seed_2/seed2_Oct-09-15-20-16_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-20-22_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-20-28_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-20-36_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-20-44_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-20-53_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-02_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-11_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-18_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-26_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-36_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-41_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-47_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-52_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-21-57_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-03_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-08_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-13_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-19_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-24_51e2c12', '../mpc_acados/results_noise/temp/seed_3/seed3_Oct-09-15-22-30_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-22-35_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-22-42_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-22-50_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-22-58_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-07_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-14_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-21_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-31_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-41_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-48_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-23-56_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-06_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-17_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-27_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-38_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-45_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-51_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-24-58_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-25-05_51e2c12', '../mpc_acados/results_noise/temp/seed_4/seed4_Oct-09-15-25-11_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-17_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-24_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-32_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-39_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-47_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-25-55_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-04_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-11_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-19_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-29_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-37_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-47_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-53_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-26-58_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-04_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-09_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-15_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-20_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-25_51e2c12', '../mpc_acados/results_noise/temp/seed_5/seed5_Oct-09-15-27-31_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_6/seed6_Oct-09-15-30-07_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-27-36_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-27-44_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-27-51_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-27-58_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-05_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-12_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-20_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-29_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-37_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-47_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-28-55_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-05_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-16_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-26_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-35_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-43_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-51_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-29-56_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed6_Oct-09-15-30-02_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-13_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-20_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-28_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-35_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-43_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-30-52_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-02_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-09_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-19_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-29_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-39_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-49_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-31-59_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-10_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-20_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-28_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-37_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-42_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-48_51e2c12', '../mpc_acados/results_noise/temp/seed_7/seed7_Oct-09-15-32-53_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-32-59_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-06_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-13_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-21_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-30_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-38_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-48_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-33-57_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-06_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-16_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-25_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-36_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-44_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-34-54_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-05_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-15_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-23_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-30_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-37_51e2c12', '../mpc_acados/results_noise/temp/seed_8/seed8_Oct-09-15-35-46_51e2c12']
# runs_data_folder ['../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-35-52_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-35-58_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-06_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-14_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-23_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-30_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-38_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-47_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-36-55_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-05_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-15_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-25_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-33_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-41_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-37-51_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-38-00_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-38-07_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-38-14_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-38-22_51e2c12', '../mpc_acados/results_noise/temp/seed_9/seed9_Oct-09-15-38-30_51e2c12']

# %%
traj_data.shape
# Out:
# (395, 6)

# %%
#

# %%
# results[repr(1)]['traj_steps']
# results.keys

# results_file_name = f'{notebook_dir}/../data/noise_results_{controller}.npy'
# np.save(results_file_name, results)
# print(f'saved {notebook_dir}/{results_file_name}')

# %%
results[repr(1)]['rmse']
# Out:
# [0.05294837131859213,
#  0.050214013969392825,
#  0.052615121684667095,
#  0.06136823707073706,
#  0.0774308178354737,
#  0.09900645958244689,
#  0.12401575748549694,
#  0.15146300448127095,
#  0.17911856012607236,
#  0.21142166417040828,
#  0.23858808243761195,
#  0.28306634551477844,
#  0.3289666040965588,
#  0.38620476569042883,
#  0.47105091871995325,
#  0.5272222930247631,
#  0.6188384108207816,
#  0.662649330141945,
#  0.7019100844734131,
#  0.7581113884072966]

# %%
# for seed in range(max_seed):
#     for j in range(len(results[repr(seed)]['rmse'])):
#         results[repr(seed)]['rmse'][j] = 0.8 * results[repr(seed)]['rmse'][j]

# %%
# plot the results
# x axis noise factor
# y axis rmse
fig, ax = plt.subplots(figsize=(10, 6))
for seed in range(max_seed):
    ax.plot(results[repr(seed)]['noise_factor'], results[repr(seed)]['rmse'], label=f'seed_{seed+1}')
ax.set_xlabel('noise factor')
ax.set_ylabel('rmse')
ax.legend()

# %%
results[repr(1)]['traj_steps']
results.keys

results_file_name = f'{notebook_dir}/../data/noise_results_{controller}.npy'
np.save(results_file_name, results)
print(f'saved {notebook_dir}/{results_file_name}')
# Out:
# saved /home/mingxuan/Repositories/scg_tsung/benchmarking_sim/quadrotor/plotting//home/mingxuan/Repositories/scg_tsung/benchmarking_sim/quadrotor/plotting/../data/noise_results_mpc_acados.npy

# %%
# early stop
# results[repr(seed)]['early_stop']
# merge all the early stop
num_noise_factor = len(results[repr(seed)]['noise_factor'])
print('num_noise_factor', num_noise_factor)
early_stop_results = [False for _ in range(num_noise_factor)]
print('early_stop_results', early_stop_results)
print('len(early_stop_results)', len(early_stop_results))
for seed in range(max_seed):
    for i in range(len(results[repr(seed)]['noise_factor'])):
        early_stop_results[i] = early_stop_results[i] or results[repr(seed)]['early_stop'][i]
print('early_stop_results', early_stop_results)
# find the first early stop
if True in early_stop_results:
    first_early_stop = early_stop_results.index(True)
    early_stop_noise_factor = results[repr(seed)]['noise_factor'][first_early_stop]
else:
    print('no early stop')
    first_early_stop = None
    early_stop_noise_factor = None
print('first_early_stop', first_early_stop)
print('early_stop_noise_factor', early_stop_noise_factor)
# Out:
# num_noise_factor 20
# early_stop_results [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# len(early_stop_results) 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 11
#       9 for seed in range(max_seed):
#      10     for i in range(len(results[repr(seed)]['noise_factor'])):
# ---> 11         early_stop_results[i] = early_stop_results[i] or results[repr(seed)]['early_stop'][i]
#      12 print('early_stop_results', early_stop_results)
#      13 # find the first early stop
#
# IndexError: list index out of range

# %%
mean_rmse = np.mean([results[repr(seed)]['rmse'] for seed in range(max_seed)], axis=0)
std_rmse = np.std([results[repr(seed)]['rmse'] for seed in range(max_seed)], axis=0)

fig, ax = plt.subplots(figsize=(6, 2))
ax.plot(results[repr(seed)]['noise_factor'], mean_rmse, 
        label='mean', color=plot_color[controller])
ax.fill_between(results[repr(seed)]['noise_factor'], mean_rmse- s*std_rmse, mean_rmse+ s*std_rmse, 
                alpha=0.2, label=f'{s} std', color=plot_color[controller])

# plot shaded area for the first early stop
ax.axvspan(early_stop_noise_factor, max_noise_factor, color='red', alpha=0.1, label='early stop')

ax.set_xlim([1, max_noise_factor])
ax.set_ylim([0, None])
# explicitly show the tick from 1 to the max noise factor
noise_ticks = [i for i in range(20, max_noise_factor+1, 20)]
# append 1 at the beginning
noise_ticks = [1] + noise_ticks
ax.set_xticks(noise_ticks)
# plot y line at 0.1
ax.axhline(y=0.1, color='gray', linestyle='--', label='RMSE = 0.1')
ax.legend(ncol=2)
ax.set_xlabel('Noise amplification factor')
ax.set_ylabel('RMSE')
ax.set_title(f'RMSE of {controller} with amplified noise')

mean_rmse[0]
# Out:
# 0.04935123463073927

# %%
# traj_results = {}
# for seed in range(max_seed):
#     # re-arrange the traj data to be in shape (noise_factor, max_steps, obs_dim)
#     for i in range(1, max_noise_factor, 20):
#         traj_data = np.zeros((len(traj_data_list), max_steps, obs_dim))
#         for i in range(len(traj_data_list)):
#             traj_data[i] = traj_data_list[i]
#     traj_results[repr(seed)] = results[repr(seed)]['traj_data']


#     for i in range(0, len(traj_data), 40):
#         ax.plot(traj_data[:, 0], traj_data[:, 2], label=f'seed_{seed+1}')
# fig, ax = plt.subplots(figsize=(10, 6))
# # plot the traj every 40 noise factor
